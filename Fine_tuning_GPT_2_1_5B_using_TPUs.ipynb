# %% [markdown]
# <a href="https://colab.research.google.com/github/GumpFang/machinelearninginaction3x/blob/master/Fine_tuning_GPT_2_1_5B_using_TPUs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/shawwn/gpt-2 /content/gpt-2 -b tpu-multi-snapshot
# %cd /content/gpt-2
# Out:
# Cloning into '/content/gpt-2'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 726 (delta 9), reused 11 (delta 4), pack-reused 710
# Receiving objects: 100% (726/726), 4.46 MiB | 15.21 MiB/s, done.
# Resolving deltas: 100% (472/472), done.
# /content/gpt-2

# %%
# !python3 download_model.py 1558M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 729kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 57.2Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 749kit/s]
# Fetching model.ckpt.data-00000-of-00001:  88%|██████████████  | 5.48G/6.23G [02:22<00:19, 38.4Mit/s]
# Fetching model.ckpt.index: 21.0kit [00:00, 11.5Mit/s]
# Fetching model.ckpt.meta: 1.84Mit [00:00, 51.2Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 52.2Mit/s]

# %%
# !pip install regex toposort magic-wormhole
# Out:
# ...
#      |████████████████████████████████| 645kB 3.3MB/s
# ...
#      |████████████████████████████████| 133kB 42.1MB/s
# ...
#      |████████████████████████████████| 3.1MB 31.2MB/s
# ...
#      |████████████████████████████████| 348kB 37.4MB/s
# ...
#      |████████████████████████████████| 778kB 38.9MB/s
# ...
#      |████████████████████████████████| 768kB 38.4MB/s
# ...
#      |████████████████████████████████| 174kB 41.7MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ...
#      |████████████████████████████████| 61kB 8.4MB/s
# ...
#      |████████████████████████████████| 2.3MB 42.0MB/s
# ...
#   Created wheel for hkdf: filename=hkdf-0.0.3-cp36-none-any.whl size=3736 sha256=708a3fc8e28d38190ca10d59bc6233faa0940c5bdd3bd25d486417556dec3d83
#   Stored in directory: /root/.cache/pip/wheels/6d/91/ba/2e93364022df91743d71cc6bd91414f29a4afd20a89a3077df
# Successfully built hkdf
# ...

# %%
# !wormhole receive 6-decadence-cranky --accept-file
# Out:
# Receiving file (17.8 MB) into: sessions-all-gpt2-nospace.txt.npz
# Receiving (->relay:tcp:transit.magic-wormhole.io:4001)..
# 100% 17.8M/17.8M [00:01<00:00, 10.2MB/s]
# Received file written to sessions-all-gpt2-nospace.txt.npz

# %%
# !PYTHONPATH=src python3 train.py  --model_name 1558M --dataset sessions-all-gpt2.txt.npz --batch_size 1 --save_every 50 --sample_every 20 --sample_num 1 --sample_length 192 --save_on_ctrlc
# Out:
# WARNING:tensorflow:From /content/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gpt-2/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# grpc://10.87.1.98:8470
# WARNING:tensorflow:From train.py:122: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:125: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
# !PYTHONPATH=src python3 train.py  --model_name 1558M --dataset sessions-all-gpt2-nospace.txt.npz --batch_size 4 --save_every 50 --sample_every 20 --sample_num 4 --sample_length 192 --save_on_ctrlc
# Out:
# WARNING:tensorflow:From /content/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gpt-2/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# grpc://10.72.96.218:8470
# WARNING:tensorflow:From train.py:122: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:125: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/shawwn/gpt-2
#    dbe2c4f..d79cd26  tpu-multi-snapshot -> origin/tpu-multi-snapshot
# Updating dbe2c4f..d79cd26
# Fast-forward
#  train.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !PYTHONPATH=src python3 train.py  --model_name 1558M --dataset sessions-all-gpt2-nospace.txt.npz --batch_size 4 --save_every 50 --sample_every 20 --sample_num 4 --sample_length 192 --save_on_ctrlc
# Out:
# WARNING:tensorflow:From /content/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gpt-2/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# grpc://10.72.96.218:8470
# WARNING:tensorflow:From train.py:122: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:125: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...
